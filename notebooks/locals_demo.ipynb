# %% [markdown]
# # How to use `locals`
# `locals` is a pure Python package that ingests JWST Wide-Field Slitless Spectroscopy (WFSS) data and returns a source catalog of all the low-mass stars in the field along with their calculated fundamental and secondary parameters.

# %%
# Imports
from locals import SourceCatalog
from sedkit import SED
import astropy.units as q
from pkg_resources import resource_filename
from bokeh.io import output_notebook, show
output_notebook()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f7ee34011bc3> in <module>
#       1 # Imports
# ----> 2 from locals import SourceCatalog
#       3 from sedkit import SED
#       4 import astropy.units as q
#       5 from pkg_resources import resource_filename
#
# ~/Documents/Modules/locals/locals/__init__.py in <module>
# ----> 1 from .catalog import SourceCatalog
#
# ~/Documents/Modules/locals/locals/catalog.py in <module>
#      16 import astropy.io.ascii as ii
#      17 from astropy.io import fits
# ---> 18 from sedkit import SED, Catalog, BTSettl
#      19
#      20 from . import colors
#
# ~/Documents/Modules/sedkit/sedkit/__init__.py in <module>
# ----> 1 from .catalog import Catalog
#       2 from .sed import SED, VegaSED
#       3 from .spectrum import Spectrum, FileSpectrum, Vega, Blackbody
#       4 from .modelgrid import ModelGrid, BTSettl, SpexPrismLibrary
#
# ~/Documents/Modules/sedkit/sedkit/catalog.py in <module>
#      21 from bokeh.models.glyphs import Patch
#      22
# ---> 23 from .sed import SED
#      24 from . import utilities as u
#      25
#
# ~/Documents/Modules/sedkit/sedkit/sed.py in <module>
#      21 from bokeh.plotting import figure, show
#      22 from bokeh.models import HoverTool, Range1d, ColumnDataSource
# ---> 23 from dustmaps.bayestar import BayestarWebQuery
#      24 from svo_filters import svo
#      25
#
# ~/miniconda3/envs/astroconda/lib/python3.5/site-packages/dustmaps/bayestar.py in <module>
#      31 import astropy.units as units
#      32 import h5py
# ---> 33 import healpy as hp
#      34
#      35 from .std_paths import *
#
# ImportError: No module named 'healpy'

# %% [markdown]
# ## Making an SED for a single source (no WFSS spectra)

# %% [markdown]
# For each spectrum in our WFSS data products, an `SED` object is created. `locals` then searches Vizier to find ancillary photometry, parallaxes, and spectral types. Then it assembles an SED from the available data and calculates fundamental and atmospheric parameters.
#
# Let's pretend one of the brown dwarfs in our field is [LHS2924](http://simbad.u-strasbg.fr/simbad/sim-id?Ident=LHS2924&NbIdent=1&Radius=2&Radius.unit=arcmin&submit=submit+id). Here is what `locals` is doing for each source under the hood.

# %%
# Coordinates of LHS 2924 (Usually taken from the WFSS source_list)
ra = 217.180137*q.deg
dec = 33.177539*q.deg

# Make the SED object
src = SED(ra=ra, dec=dec, name='LHS 2924', spectral_type='M9', radius=(1.06*q.R_jup,0.05*q.R_jup))

# Find some photometry
src.find_SDSS()
src.find_2MASS()
src.find_WISE()
src.find_PanSTARRS()

# Find a distance from Gaia DR2
src.find_Gaia()

# Take a look
print('\n',src.photometry,'\n')
# Out:
# Setting radius to (<Quantity 1.06 jupiterRad>, <Quantity 0.05 jupiterRad>)
# Setting parallax to (<Quantity 90.9962 mas>, <Quantity 0.1271 mas>) and distance to (<Quantity 10.99 pc>, <Quantity 0.02 pc>, <Quantity 0. pc>).
# 1 record for <SkyCoord (ICRS): (ra, dec) in deg
#     (217.180137, 33.177539)> found in Simbad.
# Setting name to LHS 2924 and sky_coords to <SkyCoord (ICRS): (ra, dec) in deg
#     (217.180137, 33.177539)>
# Setting age to (<Quantity 6. Gyr>, <Quantity 4. Gyr>)
# 169 records found within 20.0 arcsec of NLTT 37480 in SDSS.
# 4 records found within 20.0 arcsec of NLTT 37480 in 2MASS.
# 55 records found within 20.0 arcsec of NLTT 37480 in WISE.
# 70 records found within 20.0 arcsec of NLTT 37480 in PanSTARRS.
# 13 records found in Gaia DR2.
# Setting parallax to (<Quantity 90.9962 mas>, <Quantity 0.1271 mas>) and distance to (<Quantity 10.99 pc>, <Quantity 0.02 pc>, <Quantity 0. pc>).
#
#    band     eff   ...      ref
#             um   ...
# -------- ------- ... --------------
#   SDSS.u 0.35949 ...   V/147/sdss12
#   SDSS.g 0.46404 ...   V/147/sdss12
#    PS1.g 0.47756 ...     II/349/ps1
#   Gaia.G 0.58363 ...           None
#   SDSS.r 0.61223 ...   V/147/sdss12
#    PS1.r 0.61295 ...     II/349/ps1
#   SDSS.i 0.74395 ...   V/147/sdss12
#    PS1.i 0.74846 ...     II/349/ps1
#    PS1.z 0.86578 ...     II/349/ps1
#   SDSS.z 0.88971 ...   V/147/sdss12
#    PS1.y 0.96031 ...     II/349/ps1
#  2MASS.J   1.235 ...     II/246/out
#  2MASS.H   1.662 ...     II/246/out
# 2MASS.Ks   2.159 ...     II/246/out
#  WISE.W1  3.3526 ... II/328/allwise
#  WISE.W2  4.6028 ... II/328/allwise
#  WISE.W3 11.5608 ... II/328/allwise
#  WISE.W4 22.0883 ... II/328/allwise

# %% [markdown]
# Now we can calculate the fundamental parameters and plot the results.

# %%
src.results
# 2275K from Fili15
# Out:
# <Table length=28>
#     param             value                  unc            units
#     object            object                object          object
# ------------- --------------------- --------------------- ----------
#          Lbol              1.03e+30              1.02e+29    erg / s
#      Lbol_sun                 -3.57                 0.043         --
#          Mbol                13.679                 0.108         --
#           SpT                   M9V                    --         --
#       SpT_fit                    --                    --         --
#          Teff                  2240                    76          K
#       Teff_bb                    --                    --         --
#      Teff_evo     2334.995246583482     88.54356084564915          K
#  abs_spec_SED                    --                    --         --
#           age                   6.0                   4.0        Gyr
#           ...                   ...                   ...        ...
#          mass    0.0811883541295306 0.0031730396948613238    solMass
#          mbol                13.884                 0.108         --
#    membership                    --                    --         --
#          name              LHS 2924                    --         --
#      parallax               90.9962   0.12710000574588776        mas
#        prefix                    --                    --         --
#            ra            217.180137                    --         --
#        radius                  1.06                  0.05 jupiterRad
#     reddening 9.754067286849022e-05                    --         --
# spectral_type                  69.0                   0.5         --

# %% [markdown]
# Let's fit a blackbody for fun.

# %%
src.fit_blackbody()
# Out:
# Blackbody fit: 1831 K

# %%
fig = src.plot(integral=True)
# Out:
#   <div class="bk-root" id="02d29fcb-f32e-45b7-afb3-d1de322f4e52" data-root-id="1037"></div>

# %% [markdown]
# ## Make SEDs for all sources in the WFSS field
# Now that we see the output of a single source, we can run this on the entire `SourceCatalog` generated from the WFSS output. The difference here is that a WFSS spectrum will be included in each `Source`.
#
# Right now, we are only interested in brown dwarfs so we will include a color cut to only process sources within brown dwarf color space.

# %%
# Path to the JWST pipeline output directory
cat_path = resource_filename('locals', 'data/fake/')

# Calculate all sources in the pipeline output directory
cat = SourceCatalog(cat_path, color_cut='brown_dwarfs')
# Out:
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# <ipython-input-5-494b31a40fef> in <module>()
#       3
#       4 # Calculate all sources in the pipeline output directory
# ----> 5 cat = SourceCatalog(cat_path, color_cut='brown_dwarfs')
#
# /Users/jfilippazzo/Documents/Modules/locals/locals/catalog.py in __init__(self, dirpath, color_cut, verbose)
#      66             name = 'Source {}'.format(row['id'])
#      67             src = SED(ra=ra, dec=dec, name=name, verbose=self.verbose,
# ---> 68                       **{k:row[k] for k in row.colnames})
#      69
#      70             # Add the JWST photometry for this source
#
# /Users/jfilippazzo/Documents/Modules/SEDkit/sedkit/sed.py in __init__(self, name, verbose, method_list, **kwargs)
#     205         # Try to set attributes from kwargs
#     206         for k, v in kwargs.items():
# --> 207             setattr(self, k, v)
#     208         self.name = name
#     209
#
# /Users/jfilippazzo/Documents/Modules/SEDkit/sedkit/sed.py in dec(self, dec, dec_unc, frame)
#     662         self._dec = Angle(dec)
#     663         if self.ra is not None:
# --> 664             sky_coords = SkyCoord(ra=self.ra, dec=self.dec, unit=(q.hour, q.degree), frame='icrs')
#     665             self._set_sky_coords(sky_coords, simbad=False)
#     666
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/coordinates/sky_coordinate.py in __init__(self, copy, *args, **kwargs)
#     253             args = list(args)  # Make it mutable
#     254             skycoord_kwargs, components, info = _parse_coordinate_data(
# --> 255                 frame_cls(**frame_kwargs), args, kwargs)
#     256
#     257             # In the above two parsing functions, these kwargs were identified
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/coordinates/sky_coordinate_parsers.py in _parse_coordinate_data(frame, args, kwargs)
#     242     # Grab any frame-specific attr names like `ra` or `l` or `distance` from
#     243     # kwargs and move them to valid_components.
# --> 244     valid_components.update(_get_representation_attrs(frame, units, kwargs))
#     245
#     246     # Error if anything is still left in kwargs
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/coordinates/sky_coordinate_parsers.py in _get_representation_attrs(frame, units, kwargs)
#     587         value = kwargs.pop(frame_attr_name, None)
#     588         if value is not None:
# --> 589             valid_kwargs[frame_attr_name] = repr_attr_class(value, unit=unit)
#     590
#     591     # also check the differentials.  They aren't included in the units keyword,
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/coordinates/angles.py in __new__(cls, angle, unit, wrap_angle, **kwargs)
#     613             raise TypeError("A Longitude angle cannot be created from "
#     614                             "a Latitude angle.")
# --> 615         self = super().__new__(cls, angle, unit=unit, **kwargs)
#     616         if wrap_angle is None:
#     617             wrap_angle = getattr(angle, 'wrap_angle', self._default_wrap_angle)
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/coordinates/angles.py in __new__(cls, angle, unit, dtype, copy)
#     107                 angle = [Angle(x, unit, copy=False) for x in angle]
#     108
# --> 109         return super().__new__(cls, angle, unit, dtype=dtype, copy=copy)
#     110
#     111     @staticmethod
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/units/quantity.py in __new__(cls, value, unit, dtype, copy, order, subok, ndmin)
#     283         if isinstance(value, Quantity):
#     284             if unit is not None and unit is not value.unit:
# --> 285                 value = value.to(unit)
#     286                 # the above already makes a copy (with float dtype)
#     287                 copy = False
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/units/quantity.py in to(self, unit, equivalencies)
#     667         # and don't want to slow down this method (esp. the scalar case).
#     668         unit = Unit(unit)
# --> 669         return self._new_view(self._to_value(unit, equivalencies), unit)
#     670
#     671     def to_value(self, unit=None, equivalencies=[]):
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/units/quantity.py in _to_value(self, unit, equivalencies)
#     639             equivalencies = self._equivalencies
#     640         return self.unit.to(unit, self.view(np.ndarray),
# --> 641                             equivalencies=equivalencies)
#     642
#     643     def to(self, unit, equivalencies=[]):
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/units/core.py in to(self, other, value, equivalencies)
#     987             return UNITY
#     988         else:
# --> 989             return self._get_converter(other, equivalencies=equivalencies)(value)
#     990
#     991     def in_units(self, other, value=1.0, equivalencies=[]):
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/units/core.py in _get_converter(self, other, equivalencies)
#     918                             pass
#     919
# --> 920             raise exc
#     921
#     922     def _to(self, other):
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/units/core.py in _get_converter(self, other, equivalencies)
#     904         try:
#     905             return self._apply_equivalencies(
# --> 906                 self, other, self._normalize_equivalencies(equivalencies))
#     907         except UnitsError as exc:
#     908             # Last hope: maybe other knows how to do it?
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/units/core.py in _apply_equivalencies(self, unit, other, equivalencies)
#     888         raise UnitConversionError(
#     889             "{0} and {1} are not convertible".format(
# --> 890                 unit_str, other_str))
#     891
#     892     def _get_converter(self, other, equivalencies=[]):
#
# UnitConversionError: 'deg' (angle) and 'h' (time) are not convertible

# %% [markdown]
# All the sources are stored as `SED` instances (such as the one above) within the `SourceCatalog.sources` attribute.

# %%
# Get a source instance
source1 = cat.get_SED(0)

# Calculate the results
print(source1.results)
print('\nInput model:', source1.Teff_model, source1.logg_model, source1.FeH_model)

# Plot it
fig = source1.plot(spectra='all')
# Out:
#     param      value     unc       units
# ------------- -------- ------- -------------
#          name Source 5      --            --
#           age      6.0     4.0           Gyr
#      distance       --      --            --
#      parallax       --      --            --
#        radius       --      --            --
#           SpT       --      --            --
#       SpT_fit  Opt:M7V      --            --
# spectral_type       --      --            --
#    membership       --      --            --
#          fbol 1.89e-11 4.7e-14 erg / (cm2 s)
#          mbol   15.327   0.003            --
#          Lbol       --      --            --
#      Lbol_sun       --      --            --
#          Mbol       --      --            --
#          logg       --      --            --
#          mass       --      --            --
#          Teff       --      --            --
#       Teff_bb       --      --            --
#      Teff_evo       --      --            --
#
# Input model: 2700 4.0 0.5
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a8f1a2d9-92fd-42d9-b357-51842dd1d2d0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a8f1a2d9-92fd-42d9-b357-51842dd1d2d0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a8f1a2d9-92fd-42d9-b357-51842dd1d2d0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a8f1a2d9-92fd-42d9-b357-51842dd1d2d0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"50aa4d5a-e4cb-4003-82cc-d7a230373f9b":{"roots":{"references":[{"attributes":{"label":{"value":"Photometry"},"renderers":[{"id":"9bedb158-76ab-47bf-986c-4d1e83503a19","type":"GlyphRenderer"}]},"id":"62933f24-544d-4f21-95f8-7e56b120325b","type":"LegendItem"},{"attributes":{"data_source":{"id":"d3ceb558-34f0-4e0e-9e6b-5c0b4edaf955","type":"ColumnDataSource"},"glyph":{"id":"b1a7886f-ff4f-4aa8-be9e-d98d985bcb7a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"name":"nondetection","nonselection_glyph":{"id":"a69acabb-9a78-46d1-acd6-77eb3c2c9168","type":"Circle"},"selection_glyph":null},"id":"4d701802-a700-4688-a227-0ac14fe0c639","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e87c925-1191-430d-9c30-cd7174e756b9","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"","dtype":"float32","shape":[72]},"y":{"__ndarray__":"...","dtype":"float64","shape":[72]}}},"id":"137dffea-9b4b-4532-b9ee-798e7d38b96a","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[120]},"y":{"__ndarray__":"...","dtype":"float64","shape":[120]}}},"id":"ede322b4-b687-40a5-8093-98e4a6e49ed8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"54fc77ad-cb71-452b-bc35-9c540fd16be9","type":"Patch"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#2ca02c"},"line_alpha":{"value":0},"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f78bb89b-49dd-425c-823b-5e8f105edaa4","type":"Patch"},{"attributes":{"plot":{"id":"5f07a92f-eb7e-4e1a-87fe-47e9c69d34de","subtype":"Figure","type":"Plot"}},"id":"c5dc72e2-c900-4362-aed6-9da1ec88948f","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"","dtype":"float32","shape":[60]},"y":{"__ndarray__":"...","dtype":"float64","shape":[60]}}},"id":"d1489480-9eba-4af5-a41b-db58d0a14b9c","type":"ColumnDataSource"},{"attributes":{},"id":"e17a3357-2c10-4292-82f6-638f15a44552","type":"LogScale"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[999]},"y":{"__ndarray__":"...","dtype":"float64","shape":[999]}}},"id":"cf60086a-512d-4004-b417-a71dcaf471d0","type":"ColumnDataSource"},{"attributes":{},"id":"6ba45589-c54b-4d80-8f58-0249f7e974d1","type":"LogScale"},{"attributes":{"label":{"value":"NIRISS.F158M"},"renderers":[{"id":"88c71141-18cd-4914-a120-7f8ea3ef978f","type":"GlyphRenderer"}]},"id":"cf82bf2d-5035-4fe5-adb8-94dac532a27b","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"Gg2AP2DlgD+lvYE/6pWCPy5ugz9yRoQ/uB6FP/32hT9Cz4Y/h6eHP8t/iD8QWIk/VTCKP5oIiz/f4Is/I7mMP2eRjT+taY4/8kGPPzcakD978pA/v8qRPwWjkj9Ke5M/j1OUP9QrlT8YBJY/XdyWP6K0lz/njJg/LGWZP3A9mj+0FZs/+u2bPz/GnD+Enp0/yHaePwxPnz9SJ6A/l/+gP9zXoT8gsKI/ZIijP6pgpD/vOKU/NBGmP3nppj8=","dtype":"float32","shape":[47]},"y":{"__ndarray__":"...","dtype":"float64","shape":[47]}}},"id":"d77dd0 ...

# %% [markdown]
# Hooray! Let's take a look at another one.

# %%
# Get the source instance
source2 = cat.get_SED(1)

# Calculate the results
print(source2.results)
print('\nInput model:', source2.Teff_model, source2.logg_model, source2.FeH_model)

# Plot it
fig = source2.plot(spectra='all')
# Out:
#     param      value     unc        units
# ------------- -------- -------- -------------
#          name Source 7       --            --
#           age      6.0      4.0           Gyr
#      distance       --       --            --
#      parallax       --       --            --
#        radius       --       --            --
#           SpT       --       --            --
#       SpT_fit  Opt:M5V       --            --
# spectral_type       --       --            --
#    membership       --       --            --
#          fbol 1.89e-11 4.53e-14 erg / (cm2 s)
#          mbol   15.324    0.003            --
#          Lbol       --       --            --
#      Lbol_sun       --       --            --
#          Mbol       --       --            --
#          logg       --       --            --
#          mass       --       --            --
#          Teff       --       --            --
#       Teff_bb       --       --            --
#      Teff_evo       --       --            --
#
# Input model: 3500 3.0 0.5
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7ed35fce-f6d1-496c-8030-ac21fd9f545c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7ed35fce-f6d1-496c-8030-ac21fd9f545c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ed35fce-f6d1-496c-8030-ac21fd9f545c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ed35fce-f6d1-496c-8030-ac21fd9f545c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7efda292-03cd-41d3-9997-8facb4f6288a":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b69a5279-4a99-4941-928e-b2c537bcf07a","type":"Patch"},{"attributes":{"label":{"value":"NIRISS.F140M"},"renderers":[{"id":"81b41a60-4c3a-47fb-a44b-36c3513e4517","type":"GlyphRenderer"}]},"id":"21220e39-178b-46ba-ae4d-eb20059fbaad","type":"LegendItem"},{"attributes":{"click_policy":"hide","items":[{"id":"a8679181-9ee1-4f96-9ce9-c0de427cfd87","type":"LegendItem"},{"id":"844f10f0-6a50-4c6f-95b4-d2df943626d6","type":"LegendItem"},{"id":"21220e39-178b-46ba-ae4d-eb20059fbaad","type":"LegendItem"},{"id":"b5a2366a-485b-4020-a1d8-3502dd6251f8","type":"LegendItem"},{"id":"9477c0de-1fbe-41af-a1a0-7822fef12da6","type":"LegendItem"},{"id":"7f6e920e-7cd9-4ed6-baab-224812cbae8b","type":"LegendItem"},{"id":"32084901-8f2c-42d4-beff-8e7a90403c2a","type":"LegendItem"},{"id":"e37dd74a-8a9f-47e4-a7f4-2a9f4
ickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id": ...

# %% [markdown]
# Fantastic!
#
# Let's see a table of the results and plot all the SEDs!

# %%
cat.results[['name','spectral_type','fbol','radius','Teff_bb','SpT_fit']]
# Out:
# <Table length=5>
#    name   spectral_type          fbol          radius Teff_bb SpT_fit
#                             erg / (cm2 s)      solRad    K
#   object      object            object         object  object  object
# --------- ------------- ---------------------- ------ ------- -------
#  Source 5          None  1.890049217043731e-11   None    None Opt:M7V
#  Source 7          None 1.8946528824006648e-11   None    None Opt:M5V
# Source 11          None 3.2944384012031384e-12   None    None Opt:M4V
# Source 16          None 1.0066053621695187e-11   None    None Opt:M4V
# Source 17          None  2.012373054020361e-12   None    None Opt:M5V

# %%
# We imposed a color cut of NIRISS.F150W-NIRISS.F200W in (0.3, 0.5) and NIRISS.F158M-NIRISS.F150W in (-0.2, -0.1)
# Let's see if it worked
color = cat.plot('NIRISS.F150W-NIRISS.F200W', 'NIRISS.F158M-NIRISS.F150W')
show(color)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ab8c3778-c68d-45e0-a53a-bf9af3cd825e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ab8c3778-c68d-45e0-a53a-bf9af3cd825e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ab8c3778-c68d-45e0-a53a-bf9af3cd825e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ab8c3778-c68d-45e0-a53a-bf9af3cd825e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9249c095-4adf-43ab-a769-b61f3ad1b0e3":{"roots":{"references":[{"attributes":{"plot":null,"text":"NIRISS.F150W-NIRISS.F200W v NIRISS.F158M-NIRISS.F150W"},"id":"57bca4cd-7e84-4500-be73-ba8894fdf1c7","type":"Title"},{"attributes":{"plot":{"id":"df602d92-3739-41c7-a79c-35475a2714bc","subtype":"Figure","type":"Plot"}},"id":"7ff98060-78cd-44da-8b89-df7e1396695a","type":"SaveTool"},{"attributes":{"callback":null},"id":"221e5696-0b04-459a-9bb5-a72e975ee457","type":"DataRange1d"},{"attributes":{"label":{"value":"SED Catalog"},"renderers":[{"id":"bff1870d-c5ae-4159-966f-21ac5144ac1b","type":"GlyphRenderer"}]},"id":"83a327ad-4332-489f-9d90-d6c1830c3feb","type":"LegendItem"},{"attributes":{"callback":null,"plot":{"id":"df602d92-3739-41c7-a79c-35475a2714bc","subtype":"Figure","type":"Plot"},"tooltips":[["Name","@desc"],["NIRISS.F150W-NIRISS.F200W","@x"],["NIRISS.F158M-NIRISS.F150W","@y"]]},"id":"5a830b00-482f-4308-a078-8200083cc812","type":"HoverTool"},{"attributes":{},"id":"57e48ae1-bed4-45e4-b860-81dd29bc865a","type":"ToolEvents"},{"attributes":{"click_policy":"hide","items":[{"id":"83a327ad-4332-489f-9d90-d6c1830c3feb","type":"LegendItem"}],"plot":{"id":"df602d92-3739-41c7-a79c-35475a2714bc","subtype":"Figure","type":"Plot"}},"id":"282981db-88cb-4ef1-ac1f-1c498d3851d0","type":"Legend"},{"attributes":{"overlay":{"id":"39b8b741-e82f-41bb-88ae-8527911270ef","type":"BoxAnnotation"},"plot":{"id":"df602d92-3739-41c7-a79c-35475a2714bc","subtype":"Figure","type":"Plot"}},"id":"18211be4-6811-4484-8144-c1f15a45de27","type":"BoxZoomTool"},{"attributes":{},"id":"4880c92c-46fd-4718-8ab4-be2d69485efb","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":